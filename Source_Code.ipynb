# %% [markdown]
# Các thư viện cần thiết:

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# %% [markdown]
#  Khởi tạo Selenium:

# %%
# Đường dẫn đến ChromeDriver
driver_path = r".\chromedriver-win64\chromedriver.exe"

# Đường dẫn đến tệp thực thi của Google Chrome
chrome_path = r"C:\Program Files\Google\Chrome\Application\chrome.exe"

# Cấu hình tùy chọn Chrome
options = webdriver.ChromeOptions()
options.binary_location = chrome_path
# options.add_argument('headless')  # Chạy chế độ headless (không hiển thị giao diện)

# Tạo đối tượng Service để chỉ định đường dẫn ChromeDriver
service = Service(driver_path)

# Khởi tạo ChromeDriver với Service và các tùy chọn
driver = webdriver.Chrome(service=service, options=options)

# %% [markdown]
# Truy cập các trang web:

# %%
# Mở trang web VietnamWorks
driver.get("https://www.careerlink.vn/viec-lam/cntt-phan-mem/19") #

# %% [markdown]
# Trích xuất dữ liệu:

# %%
# Lấy danh sách các kết quả tìm kiếm
jobs = driver.find_elements(By.CLASS_NAME, 'list-group-item')
for job in jobs:
    print(job.text)
    print('-'*50)
# Out:
# Kỹ Sư IT
# CÔNG TY TNHH VACPRO VIETNAM
# Đồng Nai
# Thương lượng
# Cập nhật: 9 phút trước
# --------------------------------------------------
# Trade Marketing Executive
# Công Ty TNHH Sản Xuất Thương Mại Kỹ Thuật Á Châu
# Hồ Chí Minh
# 15 triệu - 18 triệu
# Cập nhật: một giờ trước
# --------------------------------------------------
# CHUYÊN VIÊN THIẾT KẾ ĐỒ HỌA (DESIGNER SPECIALIST)
# CÔNG TY TNHH Ô TÔ BYD (VIỆT NAM)
# Hồ Chí Minh Hà Nội
# Thương lượng
# Cập nhật: một giờ trước
# --------------------------------------------------
# KỸ SƯ IT / PHÁT TRIỂN WEB
# CareerLink Asia
# Nhật Bản
# Trên 60 triệu
# Cập nhật: một giờ trước
# --------------------------------------------------
# Software QA (Manual) - Phu Nhuan Dist.
# CareerLink's Client
# Hồ Chí Minh
# 550 USD - 1,100 USD
# Cập nhật: một giờ trước
# --------------------------------------------------
# [KỸ SƯ NỀN TẢNG REBLITZ] Tự phát triển EC quy mô lớn dựa trên nền tảng "REBLITZ"
# CareerLink Asia
# Nhật Bản
# 80 triệu - 210 triệu
# Cập nhật: một giờ trước
# --------------------------------------------------
# Tổ trưởng IT phần mềm - Nhà máy 4
# CÔNG TY TRÁCH NHIỆM HỮU HẠN SÀI GÒN PRECISION
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 17 giờ trước
# --------------------------------------------------
# NHÂN VIÊN HỖ TRỢ KỸ THUẬT SẢN PHẨM APPLE [F.STUDIO - Bảo Lộc - Lâm Đồng]
# Công Ty Cổ Phần Bán Lẻ Kỹ Thuật Số FPT
# Lâm Đồng
# 7 triệu - 12 triệu
# Cập nhật: 18 giờ trước
# --------------------------------------------------
# Nhân Viên An Ninh Mạng
# CÔNG TY TNHH SEOJIN AUTO
# Bắc Ninh
# Thương lượng
# Cập nhật: 18 giờ trước
# --------------------------------------------------
# Nhân Viên Hỗ Trợ Kỹ Thuật ĐTDĐ/LAPTOP [Ninh Kiều - Cần Thơ]
# Công Ty Cổ Phần Bán Lẻ Kỹ Thuật Số FPT
# Cần Thơ
# 7 triệu - 12 triệu
# Cập nhật: 17 giờ trước
# --------------------------------------------------
# Nhân Viên IT
# Công Ty TNHH Seojin Việt Nam
# Bắc Giang
# 10 triệu - 25 triệu
# Cập nhật: 20 giờ trước
# --------------------------------------------------
# GIÁO VIÊN TIN HỌC
# TRƯỜNG TIỂU HỌC TRUNG HỌC CƠ SỞ VÀ TRUNG HỌC PHỔ THÔNG HỒNG ĐỨC
# Hưng Yên
# 10 triệu - 12 triệu
# Cập nhật: một ngày trước
# --------------------------------------------------
# Senior Full-stack Mobile Developer
# Dreamerly
# Hồ Chí Minh
# 2,000 USD - 4,000 USD
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# QC Engineer (Mechanical Engineer) - Binh Thanh Dist. (English)
# CareerLink's Client
# Hồ Chí Minh
# 550 USD - 630 USD
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# IT Sales Representative (LAB/Remote Project Development, System Development Experience)
# Fois ICT PRO
# Hồ Chí Minh Hà Nội
# 25 triệu - 40 triệu
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# NodeJS Developer (Middle)
# Công Ty Cổ Phần Tập Đoàn Omi (OmiGroup)
# Hà Nội
# Thương lượng
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# IT Human Resource
# Fois ICT PRO
# Hồ Chí Minh
# 15 triệu - 25 triệu
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# Senior Java Developer (Tiếng Nhật N2)
# CÔNG TY TNHH QUICK VIỆT NAM
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# Nhân Viên IT Lập Trình - KCN Long Đức
# CareerLink's Client
# Đồng Nai
# 15 triệu - 17 triệu
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# Project Leader (Tiếng Nhật N3)
# CÔNG TY TNHH QUICK VIỆT NAM
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# BrSE - IT Communicator (N2 - Hà Nội)
# CareerLink's Client
# Hà Nội
# 25 triệu
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# NHÂN VIÊN KIỂM THỬ (TESTER/BA)
# Mitalab Co.,Ltd
# Hà Nội
# Cạnh tranh
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# BrSE /Project Manager (Tiếng Nhật N2 - Hà Nội)
# CareerLink's Client
# Hà Nội
# 1,500 USD - 2,500 USD
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# PHP Developer
# FPT Telecom
# Hồ Chí Minh
# 15 triệu - 30 triệu
# Cập nhật: 21 giờ trước
# --------------------------------------------------
# PHÓ TRƯỞNG KHOA CÔNG NGHỆ THÔNG TIN
# TRƯỜNG ĐẠI HỌC KINH TẾ TÀI CHÍNH TP.HCM
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 3 ngày trước
# --------------------------------------------------
# Nhân Viên Hỗ Trợ Kỹ Thuật ĐTDĐ/LAPTOP [TP.Bạc Liêu - Bạc Liêu]
# Công Ty Cổ Phần Bán Lẻ Kỹ Thuật Số FPT
# Bạc Liêu
# 8 triệu - 12 triệu
# Cập nhật: 3 ngày trước
# --------------------------------------------------
# Giảng Viên Ngành Kỹ Thuật Phần Mềm
# TRƯỜNG ĐẠI HỌC KINH TẾ TÀI CHÍNH TP.HCM
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 3 ngày trước
# --------------------------------------------------
# NHÂN VIÊN KỸ THUẬT QUY TRÌNH CẦN CÂU CÁ
# CÔNG TY TNHH DAIWA VIỆT NAM
# Đà Nẵng
# 7 triệu - 10 triệu
# Cập nhật: 13 giờ trước
# --------------------------------------------------
# Giảng Viên Ngành Công Nghệ Tài Chính
# TRƯỜNG ĐẠI HỌC KINH TẾ TÀI CHÍNH TP.HCM
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 3 ngày trước
# --------------------------------------------------
# Graphic Design (Thiết Kế Đồ Họa)
# CÔNG TY TNHH MTV HOÀNG KHANG GIANG (UOYMedia)
# Đà Nẵng
# 7 triệu - 12 triệu
# Cập nhật: 13 giờ trước
# --------------------------------------------------
# Giảng Viên Ngành Khoa Học Dữ Liệu
# TRƯỜNG ĐẠI HỌC KINH TẾ TÀI CHÍNH TP.HCM
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 3 ngày trước
# --------------------------------------------------
# EMART HEAD OFFICE_CHUYÊN VIÊN LẬP TRÌNH ỨNG DỤNG
# CÔNG TY TNHH THISO RETAIL (EMART VIET NAM)
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 3 ngày trước
# --------------------------------------------------
# Lập Trình Viên Backend (.Net)
# Công Ty Cổ Phần Dược Phẩm ECO
# Hồ Chí Minh
# 30 triệu - 40 triệu
# Cập nhật: một ngày trước
# --------------------------------------------------
# C# Developer (Junior ~ Senior) - Long Hau, Long An
# CareerLink's Client
# Long An
# 8 triệu - 40 triệu
# Cập nhật: 3 ngày trước
# --------------------------------------------------
# Tâm Anh Hà Nội - Trưởng Phòng Công Nghệ Thông Tin
# Bệnh Viện Đa Khoa Tâm Anh
# Hà Nội
# Thương lượng
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# Sales Manager (System Development / Outsourced Software )
# CareerLink's Client
# Hồ Chí Minh
# 2,500 USD - 5,000 USD
# Cập nhật: 3 ngày trước
# --------------------------------------------------
# Giảng Viên Ngành Công Nghệ Thông Tin
# TRƯỜNG ĐẠI HỌC KINH TẾ TÀI CHÍNH TP.HCM
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 4 ngày trước
# --------------------------------------------------
# Kỹ Sư Phần Mềm Di Động (Android & IOS) - Quận 3 (Tiếng Nhật hoặc Anh)
# CareerLink's Client
# Hồ Chí Minh
# 25 triệu
# Cập nhật: một ngày trước
# --------------------------------------------------
# Trưởng Bộ Phận Chuyển Đổi Số
# Tập Đoàn Vàng Bạc Đá Quý DOJI
# Hà Nội
# Thương lượng
# Cập nhật: 2 ngày trước
# --------------------------------------------------
# Nhân Viên Hỗ Trợ Kỹ Thuật ĐTDĐ/Laptop [Văn Lâm - Hưng Yên]
# Công Ty Cổ Phần Bán Lẻ Kỹ Thuật Số FPT
# Hưng Yên
# 7 triệu - 10 triệu
# Cập nhật: 4 ngày trước
# --------------------------------------------------
# TRƯỞNG PHÒNG CÔNG NGHỆ THÔNG TIN
# CÔNG TY CỔ PHẦN CÔNG NGHỆ THỰC PHẨM CHÂU Á (AFOTECH)
# Hà Nội
# Thương lượng
# Cập nhật: 4 ngày trước
# --------------------------------------------------
# Nhân Viên Hỗ Trợ Kỹ Thuật ĐTDĐ / LAPTOP [Đức Phổ - Quảng Ngãi]
# Công Ty CP Bán Lẻ Kỹ Thuật Số FPT
# Quảng Ngãi
# 5 triệu - 9 triệu
# Cập nhật: 4 ngày trước
# --------------------------------------------------
# CRM Executive
# Công Ty Cổ Phần Vàng Bạc Đá quý Phú Nhuận - PNJ
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 4 ngày trước
# --------------------------------------------------
# Nhân Viên IT
# CÔNG TY CỔ PHẦN TRUYỀN THÔNG VÀNG CHÂU Á
# Hồ Chí Minh
# 12 triệu - 15 triệu
# Cập nhật: một ngày trước
# --------------------------------------------------
# Nhân Viên IT Bệnh Viện
# CÔNG TY TNHH BỆNH VIỆN ĐA KHOA TÂM TRÍ SÀI GÒN
# Hồ Chí Minh
# Thương lượng
# Cập nhật: 19 giờ trước
# --------------------------------------------------
# Nhân Viên IT
# CÔNG TY TNHH HOJEONG
# Bắc Ninh
# Thương lượng
# Cập nhật: 8 giờ trước
# --------------------------------------------------
# NodeJS Developer
# FPT Telecom
# Hồ Chí Minh
# Thương lượng
# Cập nhật: một ngày trước
# --------------------------------------------------
# Web Developer - Huế
# CareerLink's Client
# Thừa Thiên - Huế
# 15 triệu - 60 triệu
# Cập nhật: 20 giờ trước
# --------------------------------------------------
# PHP Web Developer - Quận 1
# CareerLink's Client
# Hồ Chí Minh
# 12 triệu - 16 triệu
# Cập nhật: 21 giờ trước
# --------------------------------------------------
# Nhân Viên Hỗ Trợ Kỹ Thuật ĐTDĐ/Laptop [Cầu Giấy - Hà Nội]
# Công Ty Cổ Phần Bán Lẻ Kỹ Thuật Số FPT
# Hà Nội
# 7 triệu - 10 triệu
# Cập nhật: 3 ngày trước
# --------------------------------------------------

# %% [markdown]
# Đóng trình duyệt:

# %%
driver.quit()
